# %% [markdown]
# # Assignment 1: Vector Database Creation and Retrieval
# ## Day 6 Session 2 - RAG Fundamentals
#
# **OBJECTIVE:** Create a vector database from a folder of documents and implement basic retrieval functionality.
#
# **LEARNING GOALS:**
# - Understand document loading with SimpleDirectoryReader
# - Learn vector store setup with LanceDB
# - Implement vector index creation
# - Perform semantic search and retrieval
#
# **DATASET:** Use the data folder in `Day_6/session_2/data/` which contains multiple file types
#
# **INSTRUCTIONS:**
# 1. Complete each function by replacing the TODO comments with actual implementation
# 2. Run each cell after completing the function to test it
# 3. The answers can be found in the existing notebooks in the `llamaindex_rag/` folder

# %%
# !pip install -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (4.13.5)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (2.30.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (2.192.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (2.47.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (5.50.0)
# Requirement already satisfied: gradio_client in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (0.36.2)
# Requirement already satisfied: websockets>=15.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (15.0.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (6.17.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (7.34.0)
# Requirement already satisfied: lancedb in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.30.1)
# Requirement already satisfied: llama-index in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.14.16)
# Requirement already satisfied: llama-index-vector-stores-lancedb in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 14)) (0.5.0)
# Requirement already satisfied: llama-index-embeddings-huggingface in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: llama-index-llms-huggingface-api in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: llama-index-embeddings-openai in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 17)) (0.5.2)
# Requirement already satisfied: llama-index-llms-openrouter in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 18)) (0.5.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 20)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2.2.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (2.28.0)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (20250625)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (2.12.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (5.3.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 26)) (2026.3.17)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from -r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (3.8.11)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (1.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (0.31.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (4.9.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.135.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (26.0)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.0.22)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.24.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.42.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio_client->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (4.67.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (82.0.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (18.1.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.5)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.16 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.14.19)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.11.1)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.6.26)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.6)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.6.1)
# Requirement already satisfied: pylance in /usr/local/lib/python3.12/dist-packages (from llama-index-vector-stores-lancedb->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 14)) (3.0.1)
# Requirement already satisfied: tantivy in /usr/local/lib/python3.12/dist-packages (from llama-index-vector-stores-lancedb->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 14)) (0.25.1)
# Requirement already satisfied: llama-index-llms-openai-like<0.7,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-llms-openrouter->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 18)) (0.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2025.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.60.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (2.10.0+cpu)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (0.4.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (4.57.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.16.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.24.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (3.13.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (5.9.1)
# Requirement already satisfied: lance-namespace-urllib3-client==0.6.1 in /usr/local/lib/python3.12/dist-packages (from lance-namespace>=0.3.2->lancedb->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: urllib3<3.0.0,>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lance-namespace-urllib3-client==0.6.1->lance-namespace>=0.3.2->lancedb->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.4.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.17.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (3.6.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (4.9.4)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (9.1.4)
# Requirement already satisfied: tinytag>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.1.2)
# Requirement already satisfied: llama-cloud<2,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (6.9.2)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.20)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (3.4.6)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.1.5)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (1.14.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.7.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (7.5.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (1.23.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (3.26.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: griffecli==2.0.2 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: griffelib==2.0.2 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffecli==2.0.2->griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.4.6)

# %%
# Import required libraries
import os
from pathlib import Path
from typing import List
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, StorageContext, Settings
from llama_index.vector_stores.lancedb import LanceDBVectorStore
from llama_index.embeddings.huggingface import HuggingFaceEmbedding

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
# Configure LlamaIndex Settings (Using OpenRouter - No OpenAI API Key needed)
def setup_llamaindex_settings():
    """
    Configure LlamaIndex with local embeddings and OpenRouter for LLM.
    This assignment focuses on vector database operations, so we'll use local embeddings only.
    """
    # Check for OpenRouter API key (for future use, not needed for this basic assignment)
    api_key = os.getenv("OPENROUTER_API_KEY")
    if not api_key:
        print("ℹ️  OPENROUTER_API_KEY not found - that's OK for this assignment!")
        print("   This assignment only uses local embeddings for vector operations.")

    # Configure local embeddings (no API key required)
    Settings.embed_model = HuggingFaceEmbedding(
        model_name="BAAI/bge-small-en-v1.5",
        trust_remote_code=True
    )

    print("✅ LlamaIndex configured with local embeddings")
    print("   Using BAAI/bge-small-en-v1.5 for document embeddings")

# Setup the configuration
setup_llamaindex_settings()
# Out:
# ℹ️  OPENROUTER_API_KEY not found - that's OK for this assignment!
#    This assignment only uses local embeddings for vector operations.
# ✅ LlamaIndex configured with local embeddings
#    Using BAAI/bge-small-en-v1.5 for document embeddings

# %% [markdown]
# ## 1. Document Loading Function
#
# Complete the function below to load documents from a folder using `SimpleDirectoryReader`.
#
# **Note:** This assignment uses local embeddings only - no OpenAI API key required! We're configured to use OpenRouter for future LLM operations.

# %%
from llama_index.core import SimpleDirectoryReader

def load_documents_from_folder(folder_path: str):
    """
    Load documents from a folder using SimpleDirectoryReader.

    TODO: Complete this function to load documents from the given folder path.
    HINT: Use SimpleDirectoryReader with recursive parameter to load all files

    Args:
        folder_path (str): Path to the folder containing documents

    Returns:
        List of documents loaded from the folder
    """
    # TODO: Create SimpleDirectoryReader instance
    reader = SimpleDirectoryReader(input_dir=folder_path, recursive=True)

    # papers_folder = get_config("papers.folder")
    # print(f"Loading papers from: {papers_folder}")

    # papers_path = Path(papers_folder)
    # if not papers_path.exists():
    #     print(f"Papers folder does not exist: {papers_path}")
    #     return []


    # TODO: Load and return documents
    documents = reader.load_data()

    return documents

    # PLACEHOLDER - Replace with actual implementation
    # print(f"TODO: Load documents from {folder_path}")
    # return documents

# Test the function after you complete it
test_folder = "/content/drive/Othercomputers/My Laptop/Artificial Intelligence/Code/Repos/ai-accelerator-C5/Day_6/session_2/data"
documents = load_documents_from_folder(test_folder)
print(f"Loaded {len(documents)} documents")
# Out:
# 100%|███████████████████████████████████████| 139M/139M [00:01<00:00, 88.9MiB/s]
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Loaded 42 documents

# %% [markdown]
# ## 2. Vector Store Creation Function
#
# Complete the function below to create a LanceDB vector store.

# %%
from llama_index.vector_stores.lancedb import LanceDBVectorStore
import lancedb

def create_vector_store(db_path: str = "./vectordb", table_name: str = "documents"):
    """
    Create a LanceDB vector store for storing document embeddings.

    TODO: Complete this function to create and configure a LanceDB vector store.
    HINT: Use LanceDBVectorStore with uri and table_name parameters

    Args:
        db_path (str): Path where the vector database will be stored
        table_name (str): Name of the table in the vector database

    Returns:
        LanceDBVectorStore: Configured vector store
    """

    # TODO: Create the directory if it doesn't exist
    Path(db_path).mkdir(parents=True, exist_ok=True)

    # Connect to LanceDB
    db = lancedb.connect(str(db_path))
    print(f"✓ Connected to LanceDB at: {db_path}")

    # TODO: Create vector store
    # Create vector store
    # print(f"TODO: Create vector store at {db_path}")
    vector_store = LanceDBVectorStore(
        uri=str(db_path),
        table_name=table_name
    )
    print(f"✓ LanceDB vector store created (table: {table_name})")

    return vector_store

    # PLACEHOLDER - Replace with actual implementation
    # return None

# Test the function after you complete it
vector_store = create_vector_store("./assignment_vectordb")
print(f"Vector store created: {vector_store is not None}")
# Out:
# WARNING:llama_index.vector_stores.lancedb.base:Table documents doesn't exist yet. Please add some data to create it.
# ✓ Connected to LanceDB at: ./assignment_vectordb
# ✓ LanceDB vector store created (table: documents)
# Vector store created: True

# %% [markdown]
# ## 3. Vector Index Creation Function
#
# Complete the function below to create a vector index from documents.

# %%
from llama_index.core import StorageContext, VectorStoreIndex, load_index_from_storage
import time # Import the time module

def create_vector_index(documents: List, vector_store):
    """
    Create a vector index from documents using the provided vector store.

    TODO: Complete this function to create a VectorStoreIndex from documents.
    HINT: Create StorageContext with vector_store, then use VectorStoreIndex.from_documents()

    Args:
        documents: List of documents to index
        vector_store: LanceDB vector store to use for storage

    Returns:
        VectorStoreIndex: The created vector index
    """
    index_storage_path = "/content/assignment_vectordb"
    index_path = Path(index_storage_path)
    index_path.mkdir(parents=True, exist_ok=True)

    index = None # Initialize index to None
    storage_context = None # Initialize storage_context to None

    try:
        # Create storage context to attempt loading an existing index
        storage_context = StorageContext.from_defaults(
            persist_dir=str(index_path),
            vector_store=vector_store
        )
        # Load existing index
        index = load_index_from_storage(storage_context)
        print("✓ Successfully loaded existing index")
    except Exception as e:
        print(f"⚠️  Error loading existing index: {e}")
        print("Creating new index...")
        # If loading fails, create a new storage context for the new index
        storage_context = StorageContext.from_defaults(vector_store=vector_store)

    # Only create a new index if it wasn't loaded successfully
    if index is None:
        print("🔨 Creating new vector index...")
        start_time = time.time()

        index = VectorStoreIndex.from_documents(
            documents,
            storage_context=storage_context,
            show_progress=True
        )

        end_time = time.time()
        print(f"✓ Index created in {end_time - start_time:.2f} seconds")

        # Save index to storage
        print("💾 Saving index to storage...")
        index.storage_context.persist(persist_dir=str(index_path))
        print("✓ Index saved successfully")
    else:
        print("Index already exists and loaded, skipping creation.")

    return index

# Test the function after you complete it (will only work after previous functions are completed)
if documents and vector_store:
    index = create_vector_index(documents, vector_store)
    print(f"Vector index created: {index is not None}")
else:
    print("Complete previous functions first to test this one")
# Out:
# ✓ Successfully loaded existing index
# Index already exists and loaded, skipping creation.
# Vector index created: True

# %% [markdown]
# ## 4. Document Search Function
#
# Complete the function below to search for relevant documents using the vector index.

# %%
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever

def search_documents(index, query: str, top_k: int = 3):
    """
    Search for relevant documents using the vector index.

    TODO: Complete this function to perform semantic search on the index.
    HINT: Use index.as_retriever() with similarity_top_k parameter, then retrieve(query)

    Args:
        index: Vector index to search
        query (str): Search query
        top_k (int): Number of top results to return

    Returns:
        List of retrieved document nodes
    """
    try:
        # Create retriever from index using index.as_retriever()
        retriever = index.as_retriever(similarity_top_k=top_k)
        print(f"✓ Retriever configured to find top {top_k} similar chunks")

        # Retrieve documents for the query
        results = retriever.retrieve(query)
        return results

    except Exception as e:
        print(f"❌ Error during document search: {e}")
        return None

# Test the function after you complete it (will only work after all previous functions are completed)
if 'index' in locals() and index is not None:
    test_query = "What are AI agents?"
    results = search_documents(index, test_query, top_k=5)
    # Check if results is not None before trying to use len()
    if results is not None:
        print(f"Found {len(results)} results for query: '{test_query}'")
        for i, result in enumerate(results, 1):
            print(f"Result {i}: {result.text[:100] if hasattr(result, 'text') else 'No text'}...")
    else:
        print(f"No results found for query: '{test_query}' due to an error.")
else:
    print("Complete all previous functions first to test this one")
# Out:
# ✓ Retriever configured to find top 5 similar chunks
# Found 5 results for query: 'What are AI agents?'
# Result 1: agent-personas or the user is not needed, multi-agent architectures tend to thrive more when collabo...
# Result 2: task. In single agent patterns there is no feedback mechanism from other AI agents; however, there m...
# Result 3: THE LANDSCAPE OF EMERGING AI A GENT ARCHITECTURES
# FOR REASONING , PLANNING , AND TOOL CALLING : A S ...
# Result 4: Additionally, the open-source ecosystem continues to expand,
# with projects like CrewAI and LlamaInde...
# Result 5: system prompt for each agent can minimize excess chatter by prompting the agents not to engage in un...

# %% [markdown]
# ## 5. Final Test - Complete Pipeline
#
# Once you've completed all the functions above, run this cell to test the complete pipeline with multiple search queries.

# %%
# Final test of the complete pipeline
print("🚀 Testing Complete Vector Database Pipeline")
print("=" * 50)

# Re-run the complete pipeline to ensure everything works
data_folder = "/content/drive/Othercomputers/My Laptop/Artificial Intelligence/Code/Repos/ai-accelerator-C5/Day_6/session_2/data"
vector_db_path = "./assignment_vectordb"

# Step 1: Load documents
print("\n📂 Step 1: Loading documents...")
documents = load_documents_from_folder(data_folder)
print(f"   Loaded {len(documents)} documents")

# Step 2: Create vector store
print("\n🗄️ Step 2: Creating vector store...")
vector_store = create_vector_store(vector_db_path)
print("   Vector store status:", "✅ Created" if vector_store else "❌ Failed")

# Step 3: Create vector index
print("\n🔗 Step 3: Creating vector index...")
if documents and vector_store:
    index = create_vector_index(documents, vector_store)
    print("   Index status:", "✅ Created" if index else "❌ Failed")
else:
    index = None
    print("   ❌ Cannot create index - missing documents or vector store")

# Step 4: Test multiple search queries
print("\n🔍 Step 4: Testing search functionality...")
if index:
    search_queries = [
        "What are AI agents?",
        "How to evaluate agent performance?",
        "Italian recipes and cooking",
        "Financial analysis and investment"
    ]

    for query in search_queries:
        print(f"\n   🔎 Query: '{query}'")
        results = search_documents(index, query, top_k=2)

        if results:
            for i, result in enumerate(results, 1):
                text_preview = result.text[:100] if hasattr(result, 'text') else "No text available"
                score = f" (Score: {result.score:.4f})" if hasattr(result, 'score') else ""
                print(f"      {i}. {text_preview}...{score}")
        else:
            print("      No results found")
else:
    print("   ❌ Cannot test search - index not created")

print("\n" + "=" * 50)
print("🎯 Assignment Status:")
print(f"   Documents loaded: {'✅' if documents else '❌'}")
print(f"   Vector store created: {'✅' if vector_store else '❌'}")
print(f"   Index created: {'✅' if index else '❌'}")
print(f"   Search working: {'✅' if index else '❌'}")

if documents and vector_store and index:
    print("\n🎉 Congratulations! You've successfully completed the assignment!")
    print("   You've built a complete vector database with search functionality!")
else:
    print("\n📝 Please complete the TODO functions above to finish the assignment.")
# Out:
# 🚀 Testing Complete Vector Database Pipeline
# ==================================================
#
# 📂 Step 1: Loading documents...
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#    Loaded 42 documents
#
# 🗄️ Step 2: Creating vector store...
# ✓ Connected to LanceDB at: ./assignment_vectordb
# ✓ LanceDB vector store created (table: documents)
#    Vector store status: ✅ Created
#
# 🔗 Step 3: Creating vector index...
# ✓ Successfully loaded existing index
# Index already exists and loaded, skipping creation.
#    Index status: ✅ Created
#
# 🔍 Step 4: Testing search functionality...
#
#    🔎 Query: 'What are AI agents?'
# ✓ Retriever configured to find top 2 similar chunks
#       1. agent-personas or the user is not needed, multi-agent architectures tend to thrive more when collabo... (Score: 0.6291)
#       2. task. In single agent patterns there is no feedback mechanism from other AI agents; however, there m... (Score: 0.6115)
#
#    🔎 Query: 'How to evaluate agent performance?'
# ✓ Retriever configured to find top 2 similar chunks
#       1. steps, but the answers are limited to Yes/No responses [7]. As the industry continues to pivot towar... (Score: 0.6716)
#       2. system prompt for each agent can minimize excess chatter by prompting the agents not to engage in un... (Score: 0.6385)
#
#    🔎 Query: 'Italian recipes and cooking'
# ✓ Retriever configured to find top 2 similar chunks
#       1. # 🍝 Classic Spaghetti Carbonara Recipe
#
# ## Ingredients
# - 400g spaghetti pasta
# - 4 large egg yolk... (Score: 0.6221)
#       2. Spaghetti Carbonara, Italian, 20, Easy, Pasta, 450
# Margherita Pizza, Italian, 45, Medium, Tomato, 32... (Score: 0.5966)
#
#    🔎 Query: 'Financial analysis and investment'
# ✓ Retriever configured to find top 2 similar chunks
#       1. Stock, AAPL, Apple Inc, 10000, 12500, 25.0, Medium
# Stock, GOOGL, Alphabet Inc, 8000, 9200, 15.0, Med... (Score: 0.5631)
#       2. However, several important considerations need to be ad-
# dressed in future work:
# • Scalability: Eval... (Score: 0.5559)
#
# ==================================================
# 🎯 Assignment Status:
#    Documents loaded: ✅
#    Vector store created: ✅
#    Index created: ✅
#    Search working: ✅
#
# 🎉 Congratulations! You've successfully completed the assignment!
#    You've built a complete vector database with search functionality!
